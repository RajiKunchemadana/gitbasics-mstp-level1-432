# %% [markdown]
# # 1.print statement

# %%
print('"welcome to apssdc \n MSTp program"')
# Out:
# "welcome to apssdc
#  MSTp program"

# %% [markdown]
# # 2.one print statement

# %%
print('"***** \n **** \n ** "')
# Out:
# "*****
#  ****
#  ** "

# %% [markdown]
# # print the pi value and type that of pi task3

# %%
import math
print(math.pi)
print(type(math.pi))
# Out:
# 3.141592653589793
# <class 'float'>

# %% [markdown]
# # 4.power of 101

# %%
print(101**3)
# Out:
# 1030301

# %% [markdown]
# # 5.Average

# %%
a=23
b=46
print(a+b/2)
# Out:
# 46.0

# %% [markdown]
# # 6.conver a number into string

# %%
x=str(23)
print(type(x))
print(x)
# Out:
# <class 'str'>
# 23

# %% [markdown]
# # 7.operations

# %%
x=123
y=659
print("addition",x+y)
print("substraction",x-y)
print("multiplication",x*y)
print("division",x/y)
print("flor division",x//y)
# Out:
# addition 782
# substraction -536
# multiplication 81057
# division 0.18664643399089528
# flor division 0

# %% [markdown]
# # 8.print the values x,y,z

# %%
x=y=z="kvsw123"
print(x,y,z)
# Out:
# kvsw123 kvsw123 kvsw123

# %% [markdown]
# # Initialize the variables in a single line

# %%
x,y,z="python",31.567,6+8j
print(x,y,z)
# Out:
# python 31.567 (6+8j)

# %% [markdown]
# # print the result

# %%
x=("Python")
print("Awesome",x)
# Out:
# Awesome Python
