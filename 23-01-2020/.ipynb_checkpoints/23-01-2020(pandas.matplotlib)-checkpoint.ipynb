# %%
import pandas as pd

# %%
df=pd.read_csv("ex1.csv")
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
import sys

# %%
df.to_csv(sys.stdout)
# Out:
# ,a,b,c,d,message
# 0,1,2,3,4,hello
# 1,5,6,7,8,world
# 2,9,10,11,12,foo

# %%
df.to_csv(sys.stdout,sep='|')
# Out:
# |a|b|c|d|message
# 0|1|2|3|4|hello
# 1|5|6|7|8|world
# 2|9|10|11|12|foo

# %%
df.to_csv(sys.stdout,sep=':')
# Out:
# :a:b:c:d:message
# 0:1:2:3:4:hello
# 1:5:6:7:8:world
# 2:9:10:11:12:foo

# %%
dates=pd.date_range('1/1/2020',periods=5)
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
df1=pd.DataFrame(np.random.rand(5,4))
df1
# Out:
#           0         1         2         3
# 0  0.415839  0.416855  0.684062  0.744695
# 1  0.071359  0.759962  0.965165  0.883750
# 2  0.125269  0.621847  0.243331  0.577863
# 3  0.312204  0.784096  0.181610  0.745904
# 4  0.326840  0.432013  0.968799  0.928646

# %%
df1.index=dates
df1
# Out:
#                    0         1         2         3
# 2020-01-01  0.415839  0.416855  0.684062  0.744695
# 2020-01-02  0.071359  0.759962  0.965165  0.883750
# 2020-01-03  0.125269  0.621847  0.243331  0.577863
# 2020-01-04  0.312204  0.784096  0.181610  0.745904
# 2020-01-05  0.326840  0.432013  0.968799  0.928646

# %%
df1.index=dates
sample=df1
sample
# Out:
#                    0         1         2         3
# 2020-01-01  0.415839  0.416855  0.684062  0.744695
# 2020-01-02  0.071359  0.759962  0.965165  0.883750
# 2020-01-03  0.125269  0.621847  0.243331  0.577863
# 2020-01-04  0.312204  0.784096  0.181610  0.745904
# 2020-01-05  0.326840  0.432013  0.968799  0.928646

# %%
samplecheck=sample.to_csv('samplecheck.csv')

# %%
s=pd.read_csv("samplecheck.csv")
s
# Out:
#    Unnamed: 0         0         1         2         3
# 0  2020-01-01  0.415839  0.416855  0.684062  0.744695
# 1  2020-01-02  0.071359  0.759962  0.965165  0.883750
# 2  2020-01-03  0.125269  0.621847  0.243331  0.577863
# 3  2020-01-04  0.312204  0.784096  0.181610  0.745904
# 4  2020-01-05  0.326840  0.432013  0.968799  0.928646

# %%
# html conversion

# %%
s.to_html("htmlchecking-converted data")

# %%
excel_df=pd.read_excel("ex1.xlsx")
excel_df
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
# jsom format

# %%
j='{"name":["pandu","pinky","puppy"],"age":[23,20.19]}'
j
# Out:
# '{"name":["pandu","pinky","puppy"],"age":[23,20.19]}'

# %%
import json
r=json.loads(j)
r
# Out:
# {'name': ['pandu', 'pinky', 'puppy'], 'age': [23, 20.19]}

# %%
bank=pd.read_html('fdic_failed_bank_list.html')
bank
# Out:
# [                                  Bank Name             City  ST   CERT  \
#  0                               Allied Bank         Mulberry  AR     91
#  1              The Woodbury Banking Company         Woodbury  GA  11297
#  2                    First CornerStone Bank  King of Prussia  PA  35312
#  3                        Trust Company Bank          Memphis  TN   9956
#  4                North Milwaukee State Bank        Milwaukee  WI  20364
#  5                    Hometown National Bank         Longview  WA  35156
#  6                       The Bank of Georgia   Peachtree City  GA  35259
#  7                              Premier Bank           Denver  CO  34112
#  8                            Edgebrook Bank          Chicago  IL  57772
#  9                    Doral Bank  En Espanol         San Juan  PR  32102
#  10        Capitol City Bank & Trust Company          Atlanta  GA  33938
#  11                  Highland Community Bank          Chicago  IL  20290
# ...

# %%
len(bank)
# Out:
# 1

# %%
print(bank)
# Out:
# [                                  Bank Name             City  ST   CERT  \
# 0                               Allied Bank         Mulberry  AR     91
# 1              The Woodbury Banking Company         Woodbury  GA  11297
# 2                    First CornerStone Bank  King of Prussia  PA  35312
# 3                        Trust Company Bank          Memphis  TN   9956
# 4                North Milwaukee State Bank        Milwaukee  WI  20364
# 5                    Hometown National Bank         Longview  WA  35156
# 6                       The Bank of Georgia   Peachtree City  GA  35259
# 7                              Premier Bank           Denver  CO  34112
# 8                            Edgebrook Bank          Chicago  IL  57772
# 9                    Doral Bank  En Espanol         San Juan  PR  32102
# 10        Capitol City Bank & Trust Company          Atlanta  GA  33938
# 11                  Highland Community Bank          Chicago  IL  20290
# ...

# %%
x=bank
x1=x[0]
x1
# Out:
#                                   Bank Name             City  ST   CERT  \
# 0                               Allied Bank         Mulberry  AR     91
# 1              The Woodbury Banking Company         Woodbury  GA  11297
# 2                    First CornerStone Bank  King of Prussia  PA  35312
# 3                        Trust Company Bank          Memphis  TN   9956
# 4                North Milwaukee State Bank        Milwaukee  WI  20364
# 5                    Hometown National Bank         Longview  WA  35156
# 6                       The Bank of Georgia   Peachtree City  GA  35259
# 7                              Premier Bank           Denver  CO  34112
# 8                            Edgebrook Bank          Chicago  IL  57772
# 9                    Doral Bank  En Espanol         San Juan  PR  32102
# 10        Capitol City Bank & Trust Company          Atlanta  GA  33938
# 11                  Highland Community Bank          Chicago  IL  20290
# ...

# %%
print(type(x))
print(type(x1))
# Out:
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>

# %%
x1.head(10)
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
# 5        Hometown National Bank         Longview  WA  35156
# 6           The Bank of Georgia   Peachtree City  GA  35259
# 7                  Premier Bank           Denver  CO  34112
# 8                Edgebrook Bank          Chicago  IL  57772
# 9        Doral Bank  En Espanol         San Juan  PR  32102
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# ...

# %%
x1.tail(10)
# Out:
#                              Bank Name           City  ST   CERT  \
# 537                       NextBank, NA        Phoenix  AZ  22314
# 538           Oakwood Deposit Bank Co.        Oakwood  OH   8966
# 539              Bank of Sierra Blanca  Sierra Blanca  TX  22002
# 540      Hamilton Bank, NA  En Espanol          Miami  FL  24382
# 541             Sinclair National Bank       Gravette  AR  34248
# 542                 Superior Bank, FSB       Hinsdale  IL  32646
# 543                Malta National Bank          Malta  OH   6629
# 544    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 545  National State Bank of Metropolis     Metropolis  IL   3815
# 546                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date  \
# 537                          No Acquirer   February 7, 2002
# 538       The State Bank & Trust Company   February 1, 2002
# 539     The Security State Bank of Pecos   January 18, 2002
# ...

# %%
time=pd.to_datetime(x1["Updated Date"])
time
# Out:
# 0     2016-11-17
# 1     2016-11-17
# 2     2016-09-06
# 3     2016-09-06
# 4     2016-06-16
# 5     2016-04-13
# 6     2016-10-24
# 7     2016-08-17
# 8     2016-07-12
# 9     2015-05-13
# 10    2015-04-21
# 11    2015-04-21
# 12    2016-01-15
# 13    2016-01-06
# 14    2016-11-10
# 15    2016-01-06
# 16    2015-03-26
# 17    2015-07-28
# 18    2016-07-11
# 19    2016-03-25
# 20    2015-06-29
# 21    2015-06-26
# 22    2015-06-15
# 23    2016-11-10
# 24    2016-10-20
# 25    2014-07-18
# 26    2015-03-03
# 27    2015-03-03
# 28    2016-04-12
# 29    2016-03-25
#          ...
# 517   2012-08-28
# 518   2012-08-28
# 519   2012-10-26
# 520   2016-09-12
# 521   2012-08-28
# 522   2010-10-27
# 523   2008-04-09
# 524   2008-04-09
# 525   2012-06-05
# 526   2008-04-09
# 527   2005-07-22
# 528   2012-06-05
# 529   2008-10-20
# 530   2004-10-20
# 531   2005-03-18
# 532   2006-09-11
# 533   2008-04-09
# 534   2012-02-14
# 535   2005-03-18
# 536   2008-04-09
# 537   2015-02-05
# ...

# %%
time.dt.year.value_counts()
# Out:
# 2012    227
# 2014    109
# 2016     91
# 2015     66
# 2013     36
# 2008      6
# 2005      5
# 2004      2
# 2003      2
# 2010      1
# 2006      1
# 2002      1
# Name: Updated Date, dtype: int64

# %%
frame=pd.DataFrame(np.random.rand(5,5))
frame
# Out:
#           0         1         2         3         4
# 0  0.610765  0.791365  0.311928  0.988979  0.201698
# 1  0.516550  0.449153  0.169105  0.589560  0.180068
# 2  0.197449  0.325075  0.347836  0.527228  0.170787
# 3  0.790312  0.025445  0.493542  0.067052  0.993157
# 4  0.648803  0.122036  0.035366  0.936524  0.636254

# %%
frame.iloc[2:]
# Out:
#           0         1         2         3         4
# 2  0.197449  0.325075  0.347836  0.527228  0.170787
# 3  0.790312  0.025445  0.493542  0.067052  0.993157
# 4  0.648803  0.122036  0.035366  0.936524  0.636254

# %%
frame.iloc[2,2]
# Out:
# 0.34783643288444954

# %%
frame.iloc[2,2]=np.nan
frame
# Out:
#           0         1         2         3         4
# 0  0.610765  0.791365  0.311928  0.988979  0.201698
# 1  0.516550  0.449153  0.169105  0.589560  0.180068
# 2  0.197449  0.325075       NaN  0.527228  0.170787
# 3  0.790312  0.025445  0.493542  0.067052  0.993157
# 4  0.648803  0.122036  0.035366  0.936524  0.636254

# %%
frame.iloc[:2,0:]=np.nan
frame
# Out:
#           0         1         2         3         4
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2  0.197449  0.325075       NaN  0.527228  0.170787
# 3  0.790312  0.025445  0.493542  0.067052  0.993157
# 4  0.648803  0.122036  0.035366  0.936524  0.636254

# %%
frame.isnull()
# Out:
#        0      1      2      3      4
# 0   True   True   True   True   True
# 1   True   True   True   True   True
# 2  False  False   True  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
frame.dropna()
# Out:
#           0         1         2         3         4
# 3  0.790312  0.025445  0.493542  0.067052  0.993157
# 4  0.648803  0.122036  0.035366  0.936524  0.636254

# %%
frame.fillna(2)
# Out:
#           0         1         2         3         4
# 0  2.000000  2.000000  2.000000  2.000000  2.000000
# 1  2.000000  2.000000  2.000000  2.000000  2.000000
# 2  0.197449  0.325075  2.000000  0.527228  0.170787
# 3  0.790312  0.025445  0.493542  0.067052  0.993157
# 4  0.648803  0.122036  0.035366  0.936524  0.636254

# %%
frame.fillna({0:33,1:44,2:55})
# Out:
#            0          1          2         3         4
# 0  33.000000  44.000000  55.000000       NaN       NaN
# 1  33.000000  44.000000  55.000000       NaN       NaN
# 2   0.197449   0.325075  55.000000  0.527228  0.170787
# 3   0.790312   0.025445   0.493542  0.067052  0.993157
# 4   0.648803   0.122036   0.035366  0.936524  0.636254

# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_get_running_interactive_framework',
#  '_interactive_bk',
#  '_log',
#  '_pylab_helpers',
# ...

# %%
# types 
# plots
#* scatter plot
#* bar plot
#* histogram plot
#* pie plot

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %% [markdown]
# # Plot

# %%
x=[1,2,3,4]
y=[5,6,7,8]
plt.plot(x,y)

# %%
plt.plot(x,y,linewidth=2,markersize=10,color='black')

# %%
plt.plot(x,y,'x',linewidth=2,markersize=10,color='black')
plt.xlabel("x")
plt.ylabel("y")
plt.title("graphing")
plt.show()

# %% [markdown]
# # Bar plot

# %%
a=[1,2,3,4]
b=[5,6,7,8]
plt.bar(a,b,color='green')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar([1,2,3,4],[5,6,7,8],color='pink')
plt.bar([3,4,5,6],[7,8,9,5],color='yellow')
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Histogram

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, density=None, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, normed=None, *, data=None, **kwargs)
#     Plot a histogram.
#
#     Compute and draw the histogram of *x*.  The return value is a tuple
#     (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*, [*patches0*,
#     *patches1*,...]) if the input contains multiple data.  See the
#     documentation of the *weights* parameter to draw a histogram of
#     already-binned data.
#
#     Multiple data can be provided via *x* as a list of datasets
#     of potentially different length ([*x0*, *x1*, ...]), or as
#     a 2-D ndarray in which each column is a dataset.  Note that
#     the ndarray form is transposed relative to the list form.
#
#     Masked arrays are not supported at present.
#
#     Parameters
#     ----------
# ...

# %%
bins=[2,4,5,9]
plt.hist(x,bins)
# Out:
# (array([2., 1., 0.]), array([2, 4, 5, 9]), <a list of 3 Patch objects>)

# %%
plt.hist(x,bins,histtype='bar',orientation='horizontal')
# Out:
# (array([2., 1., 0.]), array([2, 4, 5, 9]), <a list of 3 Patch objects>)

# %%
plt.hist(x,bins,histtype='step',orientation='horizontal')
# Out:
# (array([2., 1., 0.]), array([2, 4, 5, 9]), <a list of 1 Patch objects>)

# %%
plt.hist(x,bins,histtype='bar',orientation='horizontal',rwidth=2,color='red')
# Out:
# (array([2., 1., 0.]), array([2, 4, 5, 9]), <a list of 3 Patch objects>)

# %%
import matplotlib as style

# %%
dir(style)
# Out:
# ['LooseVersion',
#  'MatplotlibDeprecationWarning',
#  'MutableMapping',
#  'Parameter',
#  'Path',
#  'RcParams',
#  'URL_REGEX',
#  '_DATA_DOC_APPENDIX',
#  '_DATA_DOC_TITLE',
#  '_ExecInfo',
#  '__bibtex__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_add_data_doc',
#  '_all_deprecated',
#  '_check_versions',
#  '_cm',
#  '_cm_listed',
#  '_color_data',
#  '_constrained_layout',
#  '_create_tmp_config_or_cache_dir',
#  '_deprecated_ignore_map',
#  '_deprecated_map',
#  '_deprecated_remain_as_none',
#  '_ensure_handler',
#  '_error_details_fmt',
#  '_get_config_or_cache_dir',
#  '_get_data_path',
#  '_get_executable_info',
#  '_get_xdg_cache_dir',
#  '_get_xdg_config_dir',
#  '_image',
#  '_init_tests',
#  '_label_from_arg',
#  '_layoutbox',
#  '_log',
#  '_logged_cached',
#  '_mathtext_data',
#  '_open_file_or_url',
#  '_path',
#  '_png',
# ...

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('classic')
plt.plot(a,b,)

# %%
plt.style.use('bmh')
plt.plot(a,b,)

# %%
plt.style.use('ggplot')
plt.plot(a,b,)

# %%
plt.style.use('fast')
plt.plot(a,b,)

# %%
x1=[2,4,6,7]
y1=[8,9,3,5]
plt.plot(x,y,color='r',label='first plot')
plt.plot(x1,y1,color='k',label='second plot')
plt.legend()

# %%
p=[1,4,6,8]
r=[9,8,7,4]
s=[5,8,7,3]
plt.stackplot(p,r,s,color=['m','k','b'])

# %% [markdown]
# # scatter plot

# %%
plt.scatter(x,y,label='plot')
plt.legend(loc="lower left")

# %% [markdown]
# # pie chart

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, data=None)
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.  If ``sum(x) < 1``, then the values of *x* give
#     the fractional area directly and the array will not be normalized. The
#     resulting pie will have an empty wedge of size ``1 - sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
#     Parameters
#     ----------
#     x : array-like
#         The wedge sizes.
#
#     explode : array-like, optional, default: None
#         If not *None*, is a ``len(x)`` array which specifies the fraction
#         of the radius with which to offset each wedge.
#
# ...

# %%
plt.pie(x,labels=y)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bbaf7d1e80>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, '5'),
#   Text(0.33991867422268784, 1.0461621742897658, '6'),
#   Text(-1.0461621902025062, 0.3399186252483017, '7'),
#   Text(0.3399188211458418, -1.0461621265515308, '8')])

# %%
plt.pie(x,labels=y,startangle=34)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bbafa3f630>,
# ...
#  [Text(0.6772276188003851, 0.8668118321377255, '5'),
#   Text(-0.3032011111986584, 1.0573878598546036, '6'),
#   Text(-1.0573878456607342, -0.30320116069855607, '7'),
#   Text(0.8668119113960023, -0.6772275173544037, '8')])

# %%
plt.pie(x,labels=y,startangle=34,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1bbafc53320>,
# ...
#  [Text(0.6772276188003851, 0.8668118321377255, '5'),
#   Text(-0.3032011111986584, 1.0573878598546036, '6'),
#   Text(-1.0573878456607342, -0.30320116069855607, '7'),
#   Text(0.8668119113960023, -0.6772275173544037, '8')],
#  [Text(0.3693968829820282, 0.4728064538933048, '10.0%'),
#   Text(-0.16538242429017727, 0.5767570144661474, '20.0%'),
#   Text(-0.5767570067240367, -0.1653824512901215, '30.0%'),
#   Text(0.47280649712509215, -0.3693968276478565, '40.0%')])

# %%
# sub plot generation

# %%
f=plt.figure()

# %%
ax1=f.add_subplot(2,2,1)
ax1

# %%
ax1.hist(np.random.rand(10),bins=[2,3,4,5])
# Out:
# (array([0., 0., 0.]), array([2, 3, 4, 5]), <a list of 3 Patch objects>)

# %% [markdown]
# ### create a data frame with studentmarks of five students and six subjects(5,6)with null values,null count, total,average, min marks,max,plot,scatterplot,stackplot

# %%
s=pd.DataFrame({"rollnumber":[431,432,433,434,435],"sub1":[23,25,26,27,28],"sub2":[28,26,27,28,29],"sub3":[29,28,26,24,27],"sub4":[22,23,24,25,26],"sub5":[27,24,26,28,29],"sub6":[17,23,29,28,20]})
s
# Out:
#    rollnumber  sub1  sub2  sub3  sub4  sub5  sub6
# 0         431    23    28    29    22    27    17
# 1         432    25    26    28    23    24    23
# 2         433    26    27    26    24    26    29
# 3         434    27    28    24    25    28    28
# 4         435    28    29    27    26    29    20

# %%
s.iloc[3,4]=np.nan
s.iloc[2,5]=np.nan
s.iloc[4,2]=np.nan
s
# Out:
#    rollnumber  sub1  sub2  sub3  sub4  sub5  sub6
# 0         431    23  28.0    29  22.0  27.0    17
# 1         432    25  26.0    28  23.0  24.0    23
# 2         433    26  27.0    26  24.0   NaN    29
# 3         434    27   NaN    24   NaN  28.0    28
# 4         435    28   NaN    27  26.0  29.0    20

# %%
s.isnull().count()
# Out:
# rollnumber    5
# sub1          5
# sub2          5
# sub3          5
# sub4          5
# sub5          5
# sub6          5
# dtype: int64
