# %% [markdown]
# # Seaborn

# %%
#-load_dataset()
#get_dataset_name()
#sb.load
# command for color--->seaborn.color_palette(pallete=none,n_color=none,desat=none)
# palette color--->geep.muted,bright,pastel,dark,colorblind
# n_color-no.ofcolors,by default-6 colors,desat-propotion to the desat

# %%
# seaborn plots--> histogramplot,bar,scatter,box,joint,distribution,violen,pair,factedgrid,relation,facted,swarm,point

# %%
import seaborn as sns

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_orig_rc_params',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'external',
#  'factorplot',
#  'get_dataset_names',
#  'heatmap',
#  'hls_palette',
#  'husl_palette',
#  'jointplot',
#  'kdeplot',
#  'light_palette',
#  'lineplot',
#  'lmplot',
#  'load_dataset',
#  'lvplot',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.rand(20)
y=np.random.rand(20)
plt.plot(x,y,'k*',alpha=0.1,linewidth=2,markersize=20)

# %%
help(sns.set)
# Out:
# Help on function set in module seaborn.rcmod:
#
# set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)
#     Set aesthetic parameters in one step.
#
#     Each set of parameters can be set directly or temporarily, see the
#     referenced functions below for more information.
#
#     Parameters
#     ----------
#     context : string or dict
#         Plotting context parameters, see :func:`plotting_context`
#     style : string or dict
#         Axes style parameters, see :func:`axes_style`
#     palette : string or sequence
#         Color palette, see :func:`color_palette`
#     font : string
#         Font family, see matplotlib font manager.
#     font_scale : float, optional
#         Separate scaling factor to independently scale the size of the
#         font elements.
#     color_codes : bool
#         If ``True`` and ``palette`` is a seaborn palette, remap the shorthand
# ...

# %%
sns.set(color_codes=True)
plt.plot(x,y)

# %%
sns.set(palette="bright",color_codes=True)
plt.plot(x,y)

# %%
import pandas as pd
data=pd.DataFrame({'x':[2,3,4,5],'y':[4,3,88,99]})
data
# Out:
#    x   y
# 0  2   4
# 1  3   3
# 2  4  88
# 3  5  99

# %%
data['x']
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# Name: x, dtype: int64

# %%
data['y']
# Out:
# 0     4
# 1     3
# 2    88
# 3    99
# Name: y, dtype: int64

# %%
plt.plot(data['x'],data['y'])

# %%
# relation plot high level functioning plot
# scatter
# line

# %%
data
# Out:
#    x   y
# 0  2   4
# 1  3   3
# 2  4  88
# 3  5  99

# %%
help(sns.relplot)
# Out:
# Help on function relplot in module seaborn.relational:
#
# relplot(x=None, y=None, hue=None, size=None, style=None, data=None, row=None, col=None, col_wrap=None, row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None, dashes=None, style_order=None, legend='brief', kind='scatter', height=5, aspect=1, facet_kws=None, **kwargs)
#     Figure-level interface for drawing relational plots onto a FacetGrid.
#
#     This function provides access to several different axes-level functions
#     that show the relationship between two variables with semantic mappings
#     of subsets. The ``kind`` parameter selects the underlying axes-level
#     function to use:
#
#     - :func:`scatterplot` (with ``kind="scatter"``; the default)
#     - :func:`lineplot` (with ``kind="line"``)
#
#     Extra keyword arguments are passed to the underlying function, so you
# ...

# %%
sns.set()
sns.relplot(x='x',y='y',data=data)

# %%
sns.relplot(x='x',y='y',data=data,kind='line')

# %%
sns.relplot(x='x',y='y',data=data,hue='y',kind='line')

# %%
# Loading a datasets
sns.get_dataset_names()
# Out:
# C:\Users\public\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\public\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
t=sns.load_dataset('tips')
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='day',data=t)

# %%
sns.relplot(x='total_bill',y='day',data=t,hue='tip')

# %%
sns.relplot(x='total_bill',y='size',data=t,hue='tip',kind="line")

# %%
# load the iries dataset
t1=sns.load_dataset("iris")
t1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
t1['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
sns.relplot(x='sepal_length',y='petal_length',data=t1)

# %%
sns.relplot(x='sepal_length',y='petal_length',data=t1,hue='petal_length',kind="line")

# %%
sns.relplot(x='sepal_length',y='petal_length',data=t1,hue='petal_length')

# %%
sns.relplot(x='sepal_length',y='petal_length',data=t1,hue='petal_length',col='species')

# %%
# flights

# %%
t2=sns.load_dataset("flights")
t2.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.relplot(x="month",y='passengers',data=t2,hue='passengers')

# %%
sns.relplot('total_bill','tip',data=t,style="smoker",size='size',col='time')

# %%
sns.relplot('total_bill','tip',data=t,style="smoker",size='size',col='time',legend='full')

# %%
# liner regression model plot

# %%
sns.lmplot('total_bill','tip',data=t,hue='smoker',col='time',legend='full')

# %%
# categorical data plot
# cat plot
     # swarm plot
    # scatter plot
    # bar plot
    # voilne plot

# %%
sns.catplot(x='species',y='petal_length',data=t1)

# %%
sns.catplot(x='species',y='petal_length',data=t1,hue='sepal_width')

# %%
sns.catplot(x='species',y='petal_length',data=t1,hue='sepal_width',kind='swarm')

# %%
sns.catplot(x='species',y='petal_length',data=t1,kind='violin')

# %%
sns.barplot(x='species',y='petal_length',data=t1)

# %%
# box plot
f,axs=plt.subplots(1,2)
sns.boxplot(x='species',y='sepal_length',data=t1,ax=axs[0])
sns.scatterplot(x='species',y='sepal_length',hue="sepal_width",data=t1)

# %%
sns.swarmplot(x='total_bill',y='day',data=t)

# %%
sns.boxplot(x='species',y='petal_length',hue="sepal_width",data=t1)

# %%
# visualisation of dataset
# joint plot
# kde-kernal density
# hex
# reg
# scatter

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(x, y, data=None, kind='scatter', stat_func=None, color=None, height=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None, marginal_kws=None, annot_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     x, y : strings or vectors
#         Data or names of variables in ``data``.
#     data : DataFrame, optional
#         DataFrame when ``x`` and ``y`` are variable names.
#     kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }, optional
#         Kind of plot to draw.
#     stat_func : callable or None, optional
#         *Deprecated*
# ...

# %%
sns.jointplot("total_bill","tip",data=t)

# %%
sns.jointplot('total_bill','tip',data=t,kind='kde')

# %%
sns.jointplot('total_bill','tip',data=t,kind='kde',hue='smoker')
# Out:
# C:\Users\public\Anaconda3\lib\site-packages\seaborn\distributions.py:423: UserWarning: The following kwargs were not used by contour: 'hue'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)

# %%
sns.jointplot('total_bill','tip',data=t,kind='hex')

# %%
sns.jointplot('total_bill','tip',data=t,kind='reg',color='g')

# %%
sns.jointplot('total_bill','tip',data=t,kind='reg',color='g',height=4.5,ratio=6)

# %%
# pair plot

# %%
sns.pairplot(data=t1)

# %%
sns.pairplot(data=t,hue='size')
# Out:
# C:\Users\public\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\public\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.pairplot(data=t1,hue='species',markers=["o","s","D"])

# %%
sns.pairplot(t1,vars=['sepal_width','sepal_length',"petal_width",'petal_length'])

# %%
sns.pairplot(t1,vars=['sepal_width','sepal_length'])

# %%
sns.pairplot(t1,diag_kind='kde')

# %%
sns.pairplot(t1,diag_kind='reg',markers="*")

# %%
# Distributed plot

# %%
x=np.random.rand(50)
sns.distplot(x)

# %%
# facetgrid plot

# %%
ff=sns.FacetGrid(t1,col='species')
ff.map(plt.hist,'sepal_length')

# %%
# tipstatus
ff=sns.FacetGrid(t,col='size')
ff.map(plt.hist,'tip')

# %%
# pair grid
pp=sns.PairGrid(t1)
pp.map(plt.scatter)
